# %%
from google.colab import files

# Upload your file
uploaded = files.upload()

# Print the name of the uploaded file
for filename in uploaded.keys():
    print("✅ Uploaded file name:", filename)
# Out:
#      <input type="file" id="files-3802e381-5786-49f1-8cd7-e97fd0ffd12d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3802e381-5786-49f1-8cd7-e97fd0ffd12d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("HW2-Data-2.xlsx - Sheet1.csv")
df.head()
# Out:
#    Number  0-10\n %3\n HW1\n   0-10\n %3\n Q1\n   0-10\n %3\n Q2\n   \
# 0       1                10.0                4.0               10.0
# 1       2                10.0                NaN                NaN
# 2       3                10.0                4.0                9.0
# 3       4                10.0                NaN                NaN
# 4       5                10.0                NaN                NaN
#
#    0-10\n %3\n Q3\n   0-10\n %3\n Q4\n   0-10\n %3\n Q5\n   \
# 0                5.0                8.0                8.0
# 1                NaN                NaN                NaN
# 2               10.0                9.0                9.0
# 3               10.0                NaN                NaN
# 4                NaN                NaN                NaN
#
#    0-100\n %15\n Midterm\n   0-100\n %40\n Proj\n   \
# 0                      60.0                     78
# 1                       NaN                      0
# ...

# %%
df.columns = df.columns.str.replace('\n', ' ', regex=True).str.replace(' +', ' ', regex=True).str.strip()
df.columns
# Out:
# Index(['Number', '0-10 %3 HW1', '0-10 %3 Q1', '0-10 %3 Q2', '0-10 %3 Q3',
#        '0-10 %3 Q4', '0-10 %3 Q5', '0-100 %15 Midterm', '0-100 %40 Proj',
#        '0-100 %25 Final Exam', 'Total Grade', 'Dataset', 'Manual Category',
#        'KNN results', 'Match result successful', 'Match result failing',
#        'Distance to student 3', 'Distance to student 4',
#        'Distance to student 5', 'Distance to student 13',
#        'Distance to student 14', 'Distance to student 15',
#        'Distance to student 16', 'Distance to student 21',
#        'Distance to student 22', 'Distance to student 23',
#        'Distance to student 30', 'Distance to student 31',
#        'Distance to student 32', 'Distance to student 36',
#        'Distance to student 37', 'Distance to student 38',
#        'Distance to student 39', 'Distance to student 40',
#        'Distance to student 41', 'Distance to student 42'],
#       dtype='object')

# %%
for i, col in enumerate(df.columns):
    print(f"{i}: {col}")
# Out:
# 0: Number
# 1: 0-10 %3 HW1
# 2: 0-10 %3 Q1
# 3: 0-10 %3 Q2
# 4: 0-10 %3 Q3
# 5: 0-10 %3 Q4
# 6: 0-10 %3 Q5
# 7: 0-100 %15 Midterm
# 8: 0-100 %40 Proj
# 9: 0-100 %25 Final Exam
# 10: Total Grade
# 11: Dataset
# 12: Manual Category
# 13: KNN results
# 14: Match result successful
# 15: Match result failing
# 16: Distance to student 3
# 17: Distance to student 4
# 18: Distance to student 5
# 19: Distance to student 13
# 20: Distance to student 14
# 21: Distance to student 15
# 22: Distance to student 16
# 23: Distance to student 21
# 24: Distance to student 22
# 25: Distance to student 23
# 26: Distance to student 30
# 27: Distance to student 31
# 28: Distance to student 32
# 29: Distance to student 36
# 30: Distance to student 37
# 31: Distance to student 38
# 32: Distance to student 39
# 33: Distance to student 40
# 34: Distance to student 41
# 35: Distance to student 42

# %%
features = ['0-100 %40 Proj', '0-100 %25 Final Exam']


train_df = df[df['Dataset'] == 'train']
test_df = df[df['Dataset'] == 'test']

X_train = train_df[features]
y_train = train_df['Manual Category']

X_test = test_df[features]
y_test = test_df['Manual Category']

# %%
df['Dataset'].unique()
# Out:
# array(['Train', 'Test', 'Test ', 'Train '], dtype=object)

# %%
df.update(predicted_df)


df.to_csv("HW2_with_KNN_results.csv", index=False)

from google.colab import files
files.download("HW2_with_KNN_results.csv")

# %%
def get_confusion_label(true, pred, positive_class='Failing'):
    if true == positive_class and pred == positive_class:
        return 'True Positive'
    elif true != positive_class and pred != positive_class:
        return 'True Negative'
    elif true != positive_class and pred == positive_class:
        return 'False Positive'
    elif true == positive_class and pred != positive_class:
        return 'False Negative'
    else:
        return 'Other'  # just in case

# Apply to your predicted_df (cleaned test set)
predicted_df['Confusion Result'] = [
    get_confusion_label(true, pred)
    for true, pred in zip(predicted_df['Manual Category'], predicted_df['KNN results'])
]

# %%
df.update(predicted_df)


df.to_csv("HW2_with_KNN_and_Confusion.csv", index=False)


from google.colab import files
files.download("HW2_with_KNN_and_Confusion.csv")

# %%
def get_confusion_label(true, pred, positive_class='Failing'):
    if true == positive_class and pred == positive_class:
        return 'True Positive'
    elif true != positive_class and pred != positive_class:
        return 'True Negative'
    elif true != positive_class and pred == positive_class:
        return 'False Positive'
    elif true == positive_class and pred != positive_class:
        return 'False Negative'

# Apply the function to each row of the predicted_df
predicted_df['Confusion Result'] = [
    get_confusion_label(true, pred)
    for true, pred in zip(predicted_df['Manual Category'], predicted_df['KNN results'])
]

# %%
predicted_df[['Manual Category', 'KNN results', 'Confusion Result']].head(10)
# Out:
#    Manual Category KNN results Confusion Result
# 2       Successful  Successful    True Negative
# 3       Successful  Successful    True Negative
# 11         Failing  Successful   False Negative
# 12         Failing     Failing    True Positive
# 13      Successful  Successful    True Negative
# 14      Successful  Successful    True Negative
# 19         Failing  Successful   False Negative
# 20         Failing  Successful   False Negative
# 28         Failing     Failing    True Positive
# 29         Failing     Failing    True Positive

# %%
df.update(predicted_df)

# %%
df.to_csv("HW2_with_KNN_and_Confusion.csv", index=False)

from google.colab import files
files.download("HW2_with_KNN_and_Confusion.csv")

# %%
def get_confusion_label(true, pred, positive_class='Failing'):
    if true == positive_class and pred == positive_class:
        return 'True Positive'
    elif true != positive_class and pred != positive_class:
        return 'True Negative'
    elif true != positive_class and pred == positive_class:
        return 'False Positive'
    elif true == positive_class and pred != positive_class:
        return 'False Negative'

# %%
predicted_df[['Manual Category', 'KNN results', 'Confusion Result']].head(10)
# Out:
#    Manual Category KNN results Confusion Result
# 2       Successful  Successful    True Negative
# 3       Successful  Successful    True Negative
# 11         Failing  Successful   False Negative
# 12         Failing     Failing    True Positive
# 13      Successful  Successful    True Negative
# 14      Successful  Successful    True Negative
# 19         Failing  Successful   False Negative
# 20         Failing  Successful   False Negative
# 28         Failing     Failing    True Positive
# 29         Failing     Failing    True Positive

# %%
predicted_df = predicted_df.drop(columns=['Match result successful', 'Match result failing'], errors='ignore')

# %%
df['Dataset'] = df['Dataset'].str.strip().str.lower()

# %%
def get_confusion_label(true, pred, positive_class):
    if true == positive_class and pred == positive_class:
        return 'True Positive'
    elif true != positive_class and pred != positive_class:
        return 'True Negative'
    elif true != positive_class and pred == positive_class:
        return 'False Positive'
    elif true == positive_class and pred != positive_class:
        return 'False Negative'
    else:
        return 'Unknown'

# %%
# Column for Failing as the positive class
predicted_df['Confusion Label (Failing as Positive)'] = [
    get_confusion_label(true, pred, positive_class='Failing')
    for true, pred in zip(predicted_df['Manual Category'], predicted_df['KNN results'])
]

# Column for Successful as the positive class
predicted_df['Confusion Label (Successful as Positive)'] = [
    get_confusion_label(true, pred, positive_class='Successful')
    for true, pred in zip(predicted_df['Manual Category'], predicted_df['KNN results'])
]

# %%
predicted_df[[
    'Manual Category',
    'KNN results',
    'Confusion Label (Failing as Positive)',
    'Confusion Label (Successful as Positive)'
]].head(10)
# Out:
#    Manual Category KNN results Confusion Label (Failing as Positive)  \
# 2       Successful  Successful                         True Negative
# 3       Successful  Successful                         True Negative
# 11         Failing  Successful                        False Negative
# 12         Failing     Failing                         True Positive
# 13      Successful  Successful                         True Negative
# 14      Successful  Successful                         True Negative
# 19         Failing  Successful                        False Negative
# 20         Failing  Successful                        False Negative
# 28         Failing     Failing                         True Positive
# 29         Failing     Failing                         True Positive
#
#    Confusion Label (Successful as Positive)
# 2                             True Positive
# 3                             True Positive
# 11                           False Positive
# ...

# %%
df.update(predicted_df)

df.to_csv("HW2_with_Two_Confusion_Labels.csv", index=False)

from google.colab import files
files.download("HW2_with_Two_Confusion_Labels.csv")

# %%
train_df = df[df['Dataset'] == 'train']
test_df = df[df['Dataset'] == 'test']

# %%
print("Train samples:", len(train_df))
print("Test samples:", len(test_df))
# Out:
# Train samples: 21
# Test samples: 120

# %%
features = ['0-100 %40 Proj', '0-100 %25 Final Exam']

X_train = train_df[features]
y_train = train_df['Manual Category']

X_test = test_df[features]
y_test = test_df['Manual Category']

# %%
X_train = X_train.dropna()
y_train = y_train.loc[X_train.index]  # Keep only matching labels

X_test = X_test.dropna()
y_test = y_test.loc[X_test.index]

# %%
y_pred = knn.predict(X_test)


predicted_df = test_df.loc[X_test.index].copy()
predicted_df['KNN results'] = y_pred
predicted_df['Match result successful'] = predicted_df['KNN results'] == predicted_df['Manual Category']
predicted_df['Match result failing'] = predicted_df['KNN results'] != predicted_df['Manual Category']

# %%
from sklearn.metrics import confusion_matrix, classification_report

labels = ['Outstanding', 'Successful', 'Failing']

cm = confusion_matrix(predicted_df['Manual Category'], predicted_df['KNN results'], labels=labels)
cm_df = pd.DataFrame(cm, index=labels, columns=labels)

print("Confusion Matrix:")
print(cm_df)

print("\nClassification Report:")
print(classification_report(predicted_df['Manual Category'], predicted_df['KNN results'], labels=labels))
# Out:
# Confusion Matrix:
#              Outstanding  Successful  Failing
# Outstanding            0           0        0
# Successful             0          56        0
# Failing                0          26       28
#
# Classification Report:
#               precision    recall  f1-score   support
#
#  Outstanding       0.00      0.00      0.00         0
#   Successful       0.68      1.00      0.81        56
#      Failing       1.00      0.52      0.68        54
#
#     accuracy                           0.76       110
#    macro avg       0.56      0.51      0.50       110
# weighted avg       0.84      0.76      0.75       110
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...
